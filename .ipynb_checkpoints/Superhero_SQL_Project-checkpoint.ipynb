# %% [markdown]
# ## Superhero SQL mystery project

# %% [markdown]
# # loading and inspecting the data

# %%
import pandas as pd
import sqlite3

# %%
hero_info = pd.read_csv('CSVs/heroes_information.csv')
hero_powers = pd.read_csv('CSVs/super_hero_powers.csv')
villains = pd.read_csv('CSVs/villains.csv')
sidekicks = pd.read_csv('CSVs/sidekicks.csv')
places = pd.read_csv('CSVs/places.csv')

# %%
hero_info.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %%
hero_info.columns
# Out:
# Index(['Unnamed: 0', 'name', 'Gender', 'Eye color', 'Race', 'Hair color',
#        'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight'],
#       dtype='object')

# %%
hero_powers.head()
# Out:
#     hero_names  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# ...

# %%
hero_powers.columns
# Out:
# Index(['hero_names', 'Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=168)

# %%
villains.head()
# Out:
#    Unnamed: 0         name               real names  \
# 0           0      Magneto           Max Eisenhardt
# 1           1        Joker                  Unknown
# 2           2  Doctor Doom          Victor Von Doom
# 3           3   Lex Luthor  Alexander Joseph Luthor
# 4           4     Galactus                    Galan
#
#                                              aliases gender charecter type  \
# 0  Erik Magnus Lehnsherr, The Master of Magnetism...   Male         Mutant
# 1  "Clown Prince of Crime , Harlequin of Hate, Pu...   Male          Other
# 2  Dr. Doom, Victor von Doom, The Master, The Bar...   Male          Human
# 3  Alexander Joseph Luthor, Alexander Luthor, Ale...   Male          Human
# 4  Galan, Galen, Devourer of Worlds, Ravager of P...   Male    God/Eternal
#
#                                               powers
# 0  Blast Power, Electricity Control, Electronic D...
# 1  Adaptive, Agility, Chameleon, Enhance Mutation...
# ...

# %%
villains.columns
# Out:
# Index(['Unnamed: 0', 'name', 'real names', 'aliases', 'gender',
#        'charecter type', 'powers'],
#       dtype='object')

# %%
places.head()
# Out:
#    Unnamed: 0          location  \
# 0           0       Gotham City
# 1           1           Krypton
# 2           2           Batcave
# 3           3     Arkham Asylum
# 4           4  Castle Grayskull
#
#                                          description
# 0  Gotham City is under the protection of Batman ...
# 1  A fictional planet in the DC Universe and the ...
# 2  The Batcave is the secret headquarters for Bat...
# 3  Arkham Asylum for the Criminally Insane is a f...
# 4  At the center of the Universe; between light a...

# %%
places_cols = places.columns
hero_p_cols = hero_powers.columns
villains_cols = villains.columns
sidekicks_cols = sidekicks.columns

all_cols = places_cols, hero_p_cols, villains_cols, sidekicks_cols

# %% [markdown]
# # into the world of SQL

# %%
conn = sqlite3.connect('sql_heroes.db')
cur = conn.cursor()

# %%
###try to use an F string to automate populating the database

def columns(all_cols, conn, cur):
    
    for table_cols in all_cols:
        
        create_table_str = f'CREATE TABLE {table_cols}'
        print (create_table_str)

# %%
columns(all_cols, conn, cur)
# Out:
# CREATE TABLE Index(['Unnamed: 0', 'location', 'description'], dtype='object')
# CREATE TABLE Index(['hero_names', 'Agility', 'Accelerated Healing', 'Lantern Power Ring',
#        'Dimensional Awareness', 'Cold Resistance', 'Durability', 'Stealth',
#        'Energy Absorption', 'Flight',
#        ...
#        'Web Creation', 'Reality Warping', 'Odin Force', 'Symbiote Costume',
#        'Speed Force', 'Phoenix Force', 'Molecular Dissipation',
#        'Vision - Cryo', 'Omnipresent', 'Omniscient'],
#       dtype='object', length=168)
# CREATE TABLE Index(['Unnamed: 0', 'name', 'real names', 'aliases', 'gender',
#        'charecter type', 'powers'],
#       dtype='object')
# CREATE TABLE Index(['Unnamed: 0', 'Sidekicks', 'Aliases', 'Heroes'], dtype='object')
